# %% [markdown]
# # IMPORTING BASIC LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import basic libraries

# %%
data = pd.read_csv(r"C:\Users\Pragya\Downloads\ML Question Paper\ML Question Paper\Datasets\bank.csv",delimiter=';')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# **Data_type**

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %% [markdown]
# **Shape**

# %%
data.shape

# there are 441188 rows and 21 column in dataset.
# Out:
# (41188, 21)

# %% [markdown]
# **columns**

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# **Descriptive statistics**

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data.describe(include="all")
# Out:
#                 age     job  marital          education default housing  \
# count   41188.00000   41188    41188              41188   41188   41188
# unique          NaN      12        4                  8       3       3
# top             NaN  admin.  married  university.degree      no     yes
# freq            NaN   10422    24928              12168   32588   21576
# mean       40.02406     NaN      NaN                NaN     NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN     NaN
#
#          loan   contact  month day_of_week  ...      campaign         pdays  \
# ...

# %% [markdown]
# **Missing values**

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# **Checking normality distribution of variables**

# %%
numerical_var = data.select_dtypes(include=['int64', 'float64']).columns
data[numerical_var].hist(figsize=(15, 15), bins=30)
plt.show()

# %% [markdown]
# **Value_counts**

# %%
for i in data.columns:
    print({i:data[i].value_counts})
# Out:
# {'age': <bound method IndexOpsMixin.value_counts of 0        56
# 1        57
# 2        37
# 3        40
# 4        56
#          ..
# 41183    73
# 41184    46
# 41185    56
# 41186    44
# 41187    74
# Name: age, Length: 41188, dtype: int64>}
# {'job': <bound method IndexOpsMixin.value_counts of 0          housemaid
# 1           services
# 2           services
# 3             admin.
# 4           services
#             ...
# 41183        retired
# 41184    blue-collar
# 41185        retired
# 41186     technician
# 41187        retired
# Name: job, Length: 41188, dtype: object>}
# {'marital': <bound method IndexOpsMixin.value_counts of 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 41183    married
# 41184    married
# 41185    married
# 41186    married
# 41187    married
# Name: marital, Length: 41188, dtype: object>}
# {'education': <bound method IndexOpsMixin.value_counts of 0                   basic.4y
# ...

# %% [markdown]
# **Conclusion**
# * job:
# Most common job categories: admin, blue-collar, technician.
# Least common: students, unemployed, and unknown.
#
# * Marital Status:
# Majority are married, followed by single and divorced.
#
#
# * Education Level:
#
# Most people have a university degree or high school education.
# A small percentage are illiterate or unknown.
#
#
# * Default (Credit in Default):
#
# Majority have no default.
# Some values are unknown, which may need handling.
#
# * Housing & Personal Loan:
#
# More people have a housing loan than those who don't.
# Fewer people have personal loans.
#
#
# * Contact Method:
#
# Majority of contacts were made via cellular, while telephone usage is lower.
#
#
# * Month of Last Contact:
#
# Most contacts were made in May, July, and August.
# Very few in March, September, October, December.
#
#
# * Day of Contact:
#
# The distribution is fairly even across weekdays.
#
#
# * Previous Campaign Outcome (poutcome):
#
# Majority of previous campaign outcomes were "nonexistent".
# Few campaigns resulted in "success", meaning that conversion rates are low.

# %% [markdown]
# **Anamoly detection**

# %%
# anomoly detection :- if there are any wrong input 
for i in data.columns:
    print({i:data[i].unique()})
# Out:
# {'age': array([56, 57, 37, 40, 45, 59, 41, 24, 25, 29, 35, 54, 46, 50, 39, 30, 55,
#        49, 34, 52, 58, 32, 38, 44, 42, 60, 53, 47, 51, 48, 33, 31, 43, 36,
#        28, 27, 26, 22, 23, 20, 21, 61, 19, 18, 70, 66, 76, 67, 73, 88, 95,
#        77, 68, 75, 63, 80, 62, 65, 72, 82, 64, 71, 69, 78, 85, 79, 83, 81,
#        74, 17, 87, 91, 86, 98, 94, 84, 92, 89], dtype=int64)}
# {'job': array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', 'unknown',
#        'entrepreneur', 'student'], dtype=object)}
# {'marital': array(['married', 'single', 'divorced', 'unknown'], dtype=object)}
# {'education': array(['basic.4y', 'high.school', 'basic.6y', 'basic.9y',
#        'professional.course', 'unknown', 'university.degree',
#        'illiterate'], dtype=object)}
# {'default': array(['no', 'unknown', 'yes'], dtype=object)}
# {'housing': array(['no', 'yes', 'unknown'], dtype=object)}
# ...

# %% [markdown]
# **Conclusion :**
# --> no anamoly detected.
# --> but unknown values are found should pe handled.
# --> on later stage i will replace it with nan
# --> and nan replaced with meaningful variable

# %%
data['target'] = np.where(data['y'].isin(['yes']), 1, 0)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  target
# ...

# %% [markdown]
# **Education_column**

# %%
data["education"].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
order = data.groupby('education')['target'].mean().sort_values(ascending=False).index

import numpy as np
sns.barplot(x="education",y="target",data=data,palette="plasma",estimator=np.mean)
plt.xticks(rotation=90);

# %%
#High Performers:Illiterate (0.222): Highest success rate but likely due to vulnerabilities—avoid targeting directly. 
#University Degree (0.137) and Professional Course (0.113): Strong, desirable target audiences.

#Low Performers: Basic Education Levels (0.078–0.102): Below average,
#limited potential for targeting. Unknown (0.145): Above average but unreliable due to missing data—requires investigation.

#Actionable Insight: Focus on higher education groups (university, professional course).
#Address ethical concerns by supporting vulnerable groups (illiterate).

# %%
#Group basic.4y, basic.6y and basic.9y in one column named basic
data['education'] = data['education'].replace(
    {'basic.4y': 'basic', 'basic.6y': 'basic', 'basic.9y': 'basic'}
)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married        basic       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married        basic       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  target
# ...

# %%
#Also group illiterate and Unknown
data['education'] = data['education'].where(~data['education'].isin(['illiterate', 'unknown']), 'unknown')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married        basic       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married        basic       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  target
# ...

# %%
order = data.groupby('education')['target'].mean().sort_values(ascending=False).index

import numpy as np
sns.barplot(x="education",y="target",data=data,palette="plasma",estimator=np.mean)
plt.xticks(rotation=90);

# %% [markdown]
# **Job_columns**

# %%
print(data.groupby('job')['target'].mean())
# Out:
# job
# admin.           0.129726
# blue-collar      0.068943
# entrepreneur     0.085165
# housemaid        0.100000
# management       0.112175
# retired          0.252326
# self-employed    0.104856
# services         0.081381
# student          0.314286
# technician       0.108260
# unemployed       0.142012
# unknown          0.112121
# Name: target, dtype: float64

# %%
order = data.groupby('job')['target'].mean().sort_values(ascending=False).index

import numpy as np
sns.barplot(x="job",y="target",data=data,palette="plasma",estimator=np.mean)
plt.xticks(rotation=90);

# %%
# High Success Rates: Student (0.314) and Retired (0.252) show the highest success rates and are strong target audiences.

#Above Average: Admin (0.130) and Unemployed (0.142) are slightly above average and could be worth targeting.

#Low Success Rates: Blue-collar (0.069) and Services (0.081) have the lowest success rates, suggesting limited potential.

#Targeting Strategy: Focus on students and retired individuals.

# %%
#group unknown and unemployed into one bucket.
data['job'] = data['job'].where(~data['job'].isin(['unknown', 'unemployed']), 'unknown')

# %%
order = data.groupby('education')['target'].mean().sort_values(ascending=False).index

import numpy as np
sns.barplot(x="education",y="target",data=data,palette="plasma",estimator=np.mean)
plt.xticks(rotation=90);

# %% [markdown]
# **Marital_columns**

# %%
order = data.groupby('marital')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='marital', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %%
order = data.groupby('default')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='default', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %%
data['default'].value_counts()
# Out:
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64

# %%
data['default'] = data['default'].where(~data['default'].isin(['unknown']), 'yes')
data['default'].value_counts()
# Out:
# default
# no     32588
# yes     8600
# Name: count, dtype: int64

# %%
order = data.groupby('default')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='default', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %% [markdown]
# **Month_column**

# %%
order = data.groupby('month')['target'].mean().sort_values(ascending=False).index
plt.figure(figsize=(10,6))
sns.barplot(x='month', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %%
conditions = [
    data['month'].isin(['jan', 'feb', 'mar']),
    data['month'].isin(['apr', 'may', 'jun']),
    data['month'].isin(['jul', 'aug', 'sep']),
    data['month'].isin(['oct', 'nov', 'dec'])
]
choices = ['Q1', 'Q2', 'Q3', 'Q4']
data['qtr'] = np.select(conditions, choices, default=0)
data['qtr'].value_counts()
# Out:
# qtr
# Q2    21719
# Q3    13922
# Q4     5001
# Q1      546
# Name: count, dtype: int64

# %%
order = data.groupby('qtr')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='qtr', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %%
order = data.groupby('qtr')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='qtr', y='target', data=data, hue='contact',estimator=np.mean, order=order,palette='plasma')
plt.show()

# %% [markdown]
# **Cellular column**

# %%
data[data['contact'] == "cellular"].groupby('qtr')['target'].mean()
# Out:
# qtr
# Q1    0.518519
# Q2    0.165775
# Q3    0.115961
# Q4    0.158842
# Name: target, dtype: float64

# %% [markdown]
# **Poutcome_column**

# %%
order = data.groupby('poutcome')['target'].mean().sort_values(ascending=False).index
sns.barplot(x='poutcome', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %%
data['poutcome'] = data['poutcome'].where(~data['poutcome'].isin(['failure',  'nonexistent']), 'failure')

# %%
data['poutcome'].value_counts()
# Out:
# poutcome
# failure    39815
# success     1373
# Name: count, dtype: int64

# %% [markdown]
# **emp.var.rate_column**

# %%
order = data.groupby('emp.var.rate')['target'].mean().sort_values(ascending=False).index
plt.figure(figsize=(10,6))
sns.barplot(x='emp.var.rate', y='target', data=data, estimator=np.mean, order=order,palette='plasma')
plt.show()

# %% [markdown]
# **Subsetting column of int datatype**

# %%
for x in data.columns:
    if data[x].dtype !='object':
           print(x)
# Out:
# age
# duration
# campaign
# pdays
# previous
# emp.var.rate
# cons.price.idx
# cons.conf.idx
# euribor3m
# nr.employed
# target

# %%
A = data[["age","duration","campaign","pdays","previous","emp.var.rate","cons.price.idx","cons.conf.idx","euribor3m","nr.employed","target"]]

# %% [markdown]
# **Generating correlation matrix**

# %%
A.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
# target          0.030399  0.405274 -0.066357 -0.324914  0.230181
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# ...

# %% [markdown]
# **Generating heat map**

# %%
corr_def = A.corr(method="pearson")        
sns.heatmap(corr_def,vmax=1.0,vmin=-1.0,annot=True)
# Out:
# <Axes: >

# %%
data.drop(['emp.var.rate','euribor3m'],axis=1,inplace=True)
data.shape
# Out:
# (41188, 21)

# %% [markdown]
# * conclusion:
# --> emp.var.rate and euribor3m have a 0.972 correlation, meaning they are highly positively related.
# --> euribor3m and nr.employed have a 0.945 correlation, indicating a very strong positive relationship.
# --> emp.var.rate and nr.employed have a 0.907 correlation, which is also quite high
# --> So no need to keep that variable

# %% [markdown]
# # Q.2. Perform the following pre-processing tasks: 🡪10 marks
# a. Missing Value Analysis
# b. Label Encoding wherever required
# c. Selecting important features based on Random Forest
# d. Handling unbalanced data using SMOTE
# e. Standardize the data using any one of the scalers provided by sklearn

# %% [markdown]
# **a. Handling missing values**

# %% [markdown]
# **Replacing unknown with np.NaN**

# %%
unknown_columns = data.columns[data.isin(['unknown']).any()]
unknown_columns
# Out:
# Index(['job', 'marital', 'education', 'housing', 'loan'], dtype='object')

# %%
unknown_counts = data[['job', 'marital', 'education', 'housing', 'loan']].apply(lambda col: (col == 'unknown').sum())
print(unknown_counts)
# Out:
# job          1344
# marital        80
# education    1749
# housing       990
# loan          990
# dtype: int64

# %%
# replacing unknown value with nan
data[['job', 'marital', 'education', 'housing', 'loan']] = data[['job', 'marital', 'education', 'housing', 'loan']].replace('unknown', np.nan)

# %%
data.isnull().sum()
# Out:
# age                  0
# job               1344
# marital             80
# education         1749
# default              0
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# cons.price.idx       0
# cons.conf.idx        0
# nr.employed          0
# y                    0
# target               0
# qtr                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt
job_counts = data['job'].value_counts()

plt.figure(figsize=(8, 6))
job_counts.plot(kind='bar')  # Assign colors based on the number of classes
plt.xlabel('job')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['job'].fillna(data['job'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt
marital_counts = data['marital'].value_counts()
colors = ['lightblue', 'lightgreen', 'lightcoral']

plt.figure(figsize=(8, 6))
marital_counts.plot(kind='bar', color=colors[:len(marital_counts)])  
plt.xlabel('marital')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['marital'].fillna(data['marital'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt
education_counts = data['education'].value_counts()

plt.figure(figsize=(8, 6))
education_counts.plot(kind='bar', color=colors[:len(education_counts)])  
plt.xlabel('education')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['education'].fillna(data['education'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt
housing_counts = data['housing'].value_counts()

plt.figure(figsize=(8, 6))
housing_counts.plot(kind='bar', color=colors[:len(housing_counts)])  
plt.xlabel('housing')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['housing'].fillna(data['housing'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt
loan_counts = data['loan'].value_counts()


plt.figure(figsize=(8, 6))
loan_counts.plot(kind='bar', color=colors[:len(loan_counts)])  
plt.xlabel('Wellness Programs')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['loan'].fillna(data['loan'].mode()[0], inplace=True)

# %% [markdown]
# **b. label encoding**

# %%
colname=[]
for x in data.columns:
    if data[x].dtype=='object':
        colname.append(x)
print(colname)



# appliying fit transform method to all the columns (transform_method) i.e categorical to numerical
# For preprocessing the data
from sklearn.preprocessing import LabelEncoder
 
le=LabelEncoder()
 
for x in colname:
    data[x]=le.fit_transform(data[x])
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y', 'qtr']

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          1        1        0     0        1      6
# 2   37    7        1          1        0        1     0        1      6
# 3   40    0        1          0        0        0     0        1      6
# 4   56    7        1          1        0        0     1        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  cons.price.idx  \
# 0            1  ...         1    999         0         0          93.994
# 1            1  ...         1    999         0         0          93.994
# 2            1  ...         1    999         0         0          93.994
# 3            1  ...         1    999         0         0          93.994
# 4            1  ...         1    999         0         0          93.994
#
#    cons.conf.idx  nr.employed  y  target  qtr
# 0          -36.4       5191.0  0       0    1
# ...

# %%
data.drop(["y"],axis=1,inplace=True)
data.shape
# Out:
# (41188, 20)

# %% [markdown]
# **c. Creating X and Y**

# %%
x =data.drop(columns=['target'])

# %%
y=data['target']

# %% [markdown]
# **d. handling imbalance data using smote**

# %%
y.value_counts()
# as we see our data is for y is highly imbalanced
# Out:
# target
# 0    36548
# 1     4640
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
resampler = SMOTE()
x,y = resampler.fit_resample(x,y)
y.value_counts()
# Out:
# target
# 0    36548
# 1    36548
# Name: count, dtype: int64

# %% [markdown]
# **e. scaling data using label encoder**

# %%
# scaling our data
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()

x = sc.fit_transform(x)

# %% [markdown]
# **splitting data into train and test**

# %%
#splitting test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Q.3. Build the following Supervised Learning models: 🡪5 marks
# 	a. Logistic Regression
# 	b. Decision Trees
# 	c. Random Forest

# %% [markdown]
# # a. applying logistic regression

# %% [markdown]
# **Traning Phase**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
  
# train the model on train set
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# output is equation of liner regression 
print(lr.intercept_)   # intercept is beta-not
print(lr.coef_)     # coef is beta-1,beta-2
# Out:
# [0.06456294]
# [[-0.10764635 -0.06945716 -0.27983814 -0.07375122 -0.60707455 -0.35567885
#   -0.40572542 -0.68421564 -0.25715225 -0.18604739  2.20114008 -0.46102441
#   -0.98294405 -0.65792479 -0.08606215  0.16890638  0.35234935 -1.44342687
#   -0.26840298]]

# %%
# zipping to see kon se variable ka kya value aaya h
print(list(zip(data.columns[0:-1],lr.coef_.ravel())))
# Out:
# [('age', -0.10764635393156269), ('job', -0.06945715519896124), ('marital', -0.27983813766627913), ('education', -0.0737512190788729), ('default', -0.6070745459180815), ('housing', -0.3556788480555194), ('loan', -0.4057254179905993), ('contact', -0.6842156373748313), ('month', -0.25715225109585493), ('day_of_week', -0.18604738693260015), ('duration', 2.2011400803537375), ('campaign', -0.46102441453732834), ('pdays', -0.9829440469786839), ('previous', -0.6579247897927042), ('poutcome', -0.0860621531078914), ('cons.price.idx', 0.1689063806089638), ('cons.conf.idx', 0.35234935315357246), ('nr.employed', -1.4434268697167674), ('target', -0.26840298309299954)]

# %% [markdown]
# **Testing phase**

# %%
# Predicting the output
Y_pred = lr.predict(X_test)
print(Y_pred)
# Out:
# [1 0 1 ... 0 1 0]

# %%
# probability matrix 
Y_pred_prob = lr.predict_proba(X_test)
print(Y_pred_prob)
# Out:
# [[0.15037375 0.84962625]
#  [0.98552054 0.01447946]
#  [0.1112433  0.8887567 ]
#  ...
#  [0.97900422 0.02099578]
#  [0.04386079 0.95613921]
#  [0.93530927 0.06469073]]

# %% [markdown]
# **Evaluation phase**

# %%
#comparing Yactual v/s y_predicted
#print(list(zip(Y_test,Y_pred)))

# %% [markdown]
# **Evaluation matrix**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(y_test,Y_pred))
 
acc=accuracy_score(y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[6449  883]
#  [ 832 6456]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88      7332
#            1       0.88      0.89      0.88      7288
#
#     accuracy                           0.88     14620
#    macro avg       0.88      0.88      0.88     14620
# weighted avg       0.88      0.88      0.88     14620
#
# Accuracy of the model:  0.8826949384404925

# %% [markdown]
# # Applying Decision Tree

# %% [markdown]
# **Traning phase**

# %%
from sklearn.tree import DecisionTreeClassifier

model_DT=DecisionTreeClassifier(random_state=10, 
                                         criterion="gini")


#fit the model on the data and predict the values
model_DT.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %% [markdown]
# **Testing phase**

# %%
Y_pred=model_DT.predict(X_test)
print(Y_pred)
# Out:
# [1 0 1 ... 0 1 0]

# %% [markdown]
# **Evaluation phase**

# %%
# comparing y_actual v/s y_pred
#print(list(zip(Y_test,Y_pred)))

# %% [markdown]
# **Evaluation matrix**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
#confusion matrix
print(confusion_matrix(y_test,Y_pred))
print(accuracy_score(y_test,Y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[6692  640]
#  [ 489 6799]]
# 0.9227770177838577
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      7332
#            1       0.91      0.93      0.92      7288
#
#     accuracy                           0.92     14620
#    macro avg       0.92      0.92      0.92     14620
# weighted avg       0.92      0.92      0.92     14620

# %% [markdown]
# **Score function**

# %%
model_DT.score(X_train,y_train)
# Out:
# 1.0

# %% [markdown]
# **feature contribution**

# %%
model_DT.feature_importances_
# Out:
# array([0.04657359, 0.02607622, 0.01273289, 0.0174495 , 0.01021033,
#        0.00991441, 0.00658038, 0.06007515, 0.01273417, 0.02611727,
#        0.39151849, 0.02007213, 0.01049952, 0.01295198, 0.00256695,
#        0.04215101, 0.09496152, 0.18949915, 0.00731535])

# %% [markdown]
# **Name of variable along with their importance**

# %%
print(list(zip(data.columns[0:-1],
               model_DT.feature_importances_)))
# Out:
# [('age', 0.046573594227526986), ('job', 0.02607622404870423), ('marital', 0.012732886456331005), ('education', 0.017449499196030244), ('default', 0.010210326220735345), ('housing', 0.009914408474620847), ('loan', 0.0065803779424279335), ('contact', 0.06007514616290926), ('month', 0.012734173325388391), ('day_of_week', 0.026117272521377948), ('duration', 0.39151849415025075), ('campaign', 0.02007212604336771), ('pdays', 0.010499520885089072), ('previous', 0.012951981344773697), ('poutcome', 0.0025669459737532314), ('cons.price.idx', 0.04215100742144419), ('cons.conf.idx', 0.09496151798844048), ('nr.employed', 0.18949914746995677), ('target', 0.0073153501468720145)]

# %% [markdown]
# **creating dataframe of variable along with their importance in descending order**

# %%
sample=pd.DataFrame()

sample["Column"]= data.columns[0:-1]
sample["Imp value"]=model_DT.feature_importances_

sample.sort_values("Imp value",ascending=False)
# Out:
#             Column  Imp value
# 10        duration   0.391518
# 17     nr.employed   0.189499
# 16   cons.conf.idx   0.094962
# 7          contact   0.060075
# 0              age   0.046574
# 15  cons.price.idx   0.042151
# 9      day_of_week   0.026117
# 1              job   0.026076
# 11        campaign   0.020072
# 3        education   0.017449
# 13        previous   0.012952
# 8            month   0.012734
# 2          marital   0.012733
# 12           pdays   0.010500
# 4          default   0.010210
# 5          housing   0.009914
# 18          target   0.007315
# 6             loan   0.006580
# 14        poutcome   0.002567

# %% [markdown]
# # Applying Random Forest

# %% [markdown]
# **Traning phase**

# %%
from sklearn.ensemble import RandomForestClassifier

model_RandomForest=RandomForestClassifier(n_estimators=100,
                                          random_state=10, bootstrap=True,
                                         n_jobs=-1)

#fit the model on the data and predict the values
model_RandomForest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=10)

# %% [markdown]
# **Testing phase**

# %%
Y_pred=model_RandomForest.predict(X_test)
Y_pred
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %% [markdown]
# **Evaluation phase**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
#confusion matrix
print(confusion_matrix(y_test,Y_pred))
print(accuracy_score(y_test,Y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[6796  536]
#  [ 256 7032]]
# 0.9458276333789329
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      7332
#            1       0.93      0.96      0.95      7288
#
#     accuracy                           0.95     14620
#    macro avg       0.95      0.95      0.95     14620
# weighted avg       0.95      0.95      0.95     14620

# %% [markdown]
# **Score function**

# %%
model_RandomForest.score(X_train,y_train)
# Out:
# 0.9999828989670976

# %% [markdown]
# **contribution of variable**

# %%
model_RandomForest.feature_importances_
# Out:
# array([0.05081192, 0.0317713 , 0.01451392, 0.02262333, 0.02846296,
#        0.01879206, 0.01249031, 0.0605206 , 0.02701547, 0.02962733,
#        0.34557849, 0.02510994, 0.02632223, 0.01341359, 0.015253  ,
#        0.05958503, 0.06655489, 0.12703225, 0.02452138])

# %% [markdown]
# **Name of variable along with their contribution**

# %%
print(list(zip(data.columns[0:-1],
             model_RandomForest.feature_importances_)))
# Out:
# [('age', 0.05081191935847898), ('job', 0.03177129948393198), ('marital', 0.014513921535737223), ('education', 0.02262332740831216), ('default', 0.028462962902671987), ('housing', 0.01879205904653503), ('loan', 0.012490309271967126), ('contact', 0.06052059679089718), ('month', 0.02701547266634181), ('day_of_week', 0.02962732977338841), ('duration', 0.34557849360436554), ('campaign', 0.02510993896164131), ('pdays', 0.02632222861126608), ('previous', 0.013413591300134182), ('poutcome', 0.015252999091100655), ('cons.price.idx', 0.05958503110492197), ('cons.conf.idx', 0.06655489093932289), ('nr.employed', 0.12703224751740375), ('target', 0.024521380631581845)]

# %% [markdown]
# **creating dataframe of variable along with their importance in descending order**

# %%
sample=pd.DataFrame()

sample["Column"]= data.columns[0:-1]
sample["Imp value"] = model_RandomForest.feature_importances_

sample.sort_values("Imp value",ascending=False)
# Out:
#             Column  Imp value
# 10        duration   0.345578
# 17     nr.employed   0.127032
# 16   cons.conf.idx   0.066555
# 7          contact   0.060521
# 15  cons.price.idx   0.059585
# 0              age   0.050812
# 1              job   0.031771
# 9      day_of_week   0.029627
# 4          default   0.028463
# 8            month   0.027015
# 12           pdays   0.026322
# 11        campaign   0.025110
# 18          target   0.024521
# 3        education   0.022623
# 5          housing   0.018792
# 14        poutcome   0.015253
# 2          marital   0.014514
# 13        previous   0.013414
# 6             loan   0.012490

# %% [markdown]
# # Q.4. Tabulate the performance metrics of all the above models,perform tuning of models and tell which model performs better in predicting if the client will subscribe to term deposit or not 🡪10 marks

# %% [markdown]
# # Tunning logistic regression

# %%
# store the predicted probabilities
y_pred_prob = lr.predict_proba(X_test)



y_pred_class = []
for value in y_pred_prob[:,1]:
    if value >0.42:                         # agar value 0.5 se jayada h to consider as 1
        y_pred_class.append(1)
    else:
        y_pred_class.append(0)              # agar value 0.5 se kum h to consider as 0

# %% [markdown]
# **Evaluation matrix**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(y_test,y_pred_class)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(y_test,y_pred_class))
 
acc=accuracy_score(y_test, y_pred_class)
print("Accuracy of the model: ",acc)
# Out:
# [[6268 1064]
#  [ 618 6670]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      7332
#            1       0.86      0.92      0.89      7288
#
#     accuracy                           0.88     14620
#    macro avg       0.89      0.89      0.88     14620
# weighted avg       0.89      0.88      0.88     14620
#
# Accuracy of the model:  0.8849521203830369

# %% [markdown]
# # Pruning decision tree

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DT=DecisionTreeClassifier(random_state=10, 
                                         criterion="gini",
                                         splitter="best", 
                                         min_samples_leaf= 3,
                                         min_samples_split=3,
                                         max_depth= 3, 
                                    
                                         )

# %%
#fit the model on the data and predict the values
model_DT.fit(X_train,y_train)
Y_pred=model_DT.predict(X_test)
Y_pred
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
#confusion matrix
print(confusion_matrix(y_test,Y_pred))
print(accuracy_score(y_test,Y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[5427 1905]
#  [ 410 6878]]
# 0.841655266757866
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82      7332
#            1       0.78      0.94      0.86      7288
#
#     accuracy                           0.84     14620
#    macro avg       0.86      0.84      0.84     14620
# weighted avg       0.86      0.84      0.84     14620

# %% [markdown]
# # Pruning Random Forest

# %%
#predicting using the Random_Forest_Classifier
from sklearn.ensemble import RandomForestClassifier

model_RandomForest=RandomForestClassifier(n_estimators=300,
                                          random_state=10,
                                          bootstrap=True,
                                          min_samples_leaf= 5,
                                         n_jobs=-1)

# %%
#fit the model on the data and predict the values
model_RandomForest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=5, n_estimators=300, n_jobs=-1,
#                        random_state=10)

# %%
Y_pred=model_RandomForest.predict(X_test)
Y_pred
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
#confusion matrix
print(confusion_matrix(y_test,Y_pred))
print(accuracy_score(y_test,Y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[6688  644]
#  [ 291 6997]]
# 0.936046511627907
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      7332
#            1       0.92      0.96      0.94      7288
#
#     accuracy                           0.94     14620
#    macro avg       0.94      0.94      0.94     14620
# weighted avg       0.94      0.94      0.94     14620

# %% [markdown]
# # comparision of accuracy

# %% [markdown]
# **class 1 is my class of importance**

# %%
* Logistic Regression ---> 0.8826949384404925  ----> (recall - class_0 = 0.88 )
                                              ----> (recall - class_1 = 0.89)

* Tuned Logistic Regression --->  0.8849521203830369  ----> (recall - class_0 =0.88 )
                                              ----> (recall - class_1 = 0.89)

* Decision Tree --->  0.9227770177838577  ----> (recall - class_0 = 0.91 )
                                              ----> (recall - class_1 = 0.93)

* Pruned Decision Tree ---> 0.841655266757866 ----> (recall - class_0 = 0.74 )
                                              ----> (recall - class_1 = 0.94)

* Random Forest --->  0.9458276333789329 ----> (recall - class_0 =0.93 )
                                              ----> (recall - class_1 = 0.96)

* Pruned Random Forest ---> 0.936046511627907 ----> (recall - class_0 =0.91 )
                                              ----> (recall - class_1 = 0.96)

# %% [markdown]
# BY obesrving the accuracy of all of the models.
# Random Forest gives the best accuracy.
# So, i concluded  model "Random Forest" performs better in predicting if the client will subscribe to term deposit or not.
